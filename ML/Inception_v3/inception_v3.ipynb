# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# inception 모델 파일이 있는 위치로 폴더 경로 이동

# %%
# %cd /content/drive/My\ Drive/inception-v3/
# !ls
# Out:
# /content/drive/My Drive/inception-v3
# cat_9999.jpg  cat_test.jpeg  inception_test.py	test_set  tmp  training_set

# %%
# !ls -al
# !chmod 755 ./inception_test.py
# !ls -al
# Out:
# total 1122
# -rw------- 1 root root  20871 Jul 18 07:35  cat_9999.jpg
# -rw------- 1 root root   3611 Jul 18 09:54  cat_test.jpeg
# -rw------- 1 root root  45356 Jul 17 09:00  inception_test.py
# -rw------- 1 root root  30400 Jul 19 06:13  inception_v3.ipynb
# -rw------- 1 root root  59300 Jul 18 10:42 'inception_v3(one_image).ipynb'
# -rw------- 1 root root 969700 Jul 18 02:38 'inception_v3(test_run).ipynb'
# -rw------- 1 root root   6021 Jul 18 07:49  tensorboard_tutorial.ipynb
# drwx------ 2 root root   4096 Jul 17 09:06  test_set
# drwx------ 2 root root   4096 Jul 18 02:38  tmp
# drwx------ 2 root root   4096 Jul 17 09:06  training_set
# total 1122
# -rw------- 1 root root  20871 Jul 18 07:35  cat_9999.jpg
# -rw------- 1 root root   3611 Jul 18 09:54  cat_test.jpeg
# -rwx------ 1 root root  45356 Jul 17 09:00  inception_test.py
# -rw------- 1 root root  30400 Jul 19 06:13  inception_v3.ipynb
# -rw------- 1 root root  59300 Jul 18 10:42 'inception_v3(one_image).ipynb'
# ...

# %% [markdown]
# 파이썬을 실행하여 학습할 인셉션 모델을 호출 및 학습
#
# --image_dir='학습할 파일 경로'
#
# 이때까지 타이타닉이나 MNIST등은 csv파일로 진행했으나, 인셉션은 폴더 자체로 분류 합니다.

# %%
# !python inception_test.py --image_dir ./training_set/
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0725 11:20:02.944405 139688596748160 deprecation_wrapper.py:119] From inception_test.py:1018: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0725 11:20:02.945191 139688596748160 deprecation_wrapper.py:119] From inception_test.py:719: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# W0725 11:20:02.945501 139688596748160 deprecation_wrapper.py:119] From inception_test.py:721: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# >> Downloading inception-2015-12-05.tgz 100.0%
# Successfully downloaded inception-2015-12-05.tgz 88931400 bytes.
# W0725 11:20:06.712862 139688596748160 deprecation.py:323] From inception_test.py:212: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile.
# ...

# %% [markdown]
# bottleneck : 몇천장의 이미지를 모두 할당하지 않고 필요할 때 마다 불러오는 방식입니다<br>
# 이미지를 텍스트파일로 변경시켜 저장함으로써 용량이 작아집니다.
